# %%
import pandas as pd

# %%
data = pd.read_csv("cmc.csv", names=["age","wife_ed","husb_ed","no_kids","wife_rel","wife_works",
    "husb_occupation","SOL_index","media_exp","class"])

# %%
data
# Out:
#       age  wife_ed  husb_ed  no_kids  wife_rel  wife_works  husb_occupation  \
# 0      24        2        3        3         1           1                2
# 1      45        1        3       10         1           1                3
# 2      43        2        3        7         1           1                3
# 3      42        3        2        9         1           1                3
# 4      36        3        3        8         1           1                3
# ...   ...      ...      ...      ...       ...         ...              ...
# 1468   33        4        4        2         1           0                2
# 1469   33        4        4        3         1           1                1
# 1470   39        3        3        8         1           0                1
# 1471   33        3        3        4         1           0                2
# 1472   17        3        3        1         1           1                2
#
#       SOL_index  media_exp  class
# ...

# %%
ages = pd.cut(data["age"], [16,19,29,39,49], labels=[0,1,2,3], include_lowest=True)
data["age"] = ages

# %%
kids = pd.cut(data["no_kids"], [0,0.5,4,10,16], labels=[0,1,2,3], include_lowest=True)
data["no_kids"] = kids

# %%
data["husb_occupation"] = data["husb_occupation"].map(lambda x: x-1)

# %%
for c in data.columns:
    print(c, set(data[c]))
# Out:
# age {0, 1, 2, 3}
# wife_ed {0, 1, 2, 3}
# husb_ed {0, 1, 2, 3}
# no_kids {0, 1, 2, 3}
# wife_rel {0, 1}
# wife_works {0, 1}
# husb_occupation {0, 1, 2, 3}
# SOL_index {0, 1, 2, 3}
# media_exp {0, 1}
# class {1, 2, 3}

# %%
data.to_csv("cmc_4cat.csv", index=False, header=False)
