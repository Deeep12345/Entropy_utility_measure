# %%
import pandas as pd

# %%
data = pd.read_csv("k1.csv", names=["age","wife_ed","husb_ed","no_kids","wife_rel","wife_works",
    "husb_occupation","SOL_index","media_exp","class"])

# %%
newd = data
for col in data.columns[:-1]:
    newd[f"{col}_min"] = data[col]
    newd[f"{col}_max"] = data[col]
    newd = newd.drop(col, axis=1)
    
y = newd["class"]
newd = newd.drop("class", axis=1)
newd["class"] = y
newd
# Out:
#       age_min  age_max  wife_ed_min  wife_ed_max  husb_ed_min  husb_ed_max  \
# 0          24       24            2            2            3            3
# 1          45       45            1            1            3            3
# 2          43       43            2            2            3            3
# 3          42       42            3            3            2            2
# 4          36       36            3            3            3            3
# ...       ...      ...          ...          ...          ...          ...
# 1882       39       39            4            4            4            4
# 1883       24       24            1            1            2            2
# 1884       27       27            4            4            4            4
# 1885       35       35            1            1            2            2
# 1886       35       35            4            4            4            4
#
# ...

# %%
newd.to_csv("k1_minmaxed.csv")
