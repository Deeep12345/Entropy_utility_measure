# %%
import pandas as pd

# %%
ring = pd.read_csv("ring_randoms/metrics.csv")
ring
# Out:
#                  algo   no  precision      dm        cm   entropy   discern  \
# 0             datafly    2   0.033311  0.0800  0.397432  0.976796  0.540324
# 1    datafly_shuffled    2   0.025027  0.0325  0.433784  0.972464  0.336206
# 2            mondrian    2   0.410685  0.5875  0.235405  0.819110  0.000530
# 3             datafly    3   0.016667  0.0300  0.425811  0.992277  0.865115
# 4    datafly_shuffled    3   0.033333  0.0500  0.389730  0.940804  0.096205
# ..                ...  ...        ...     ...       ...       ...       ...
# 592  datafly_shuffled  199   0.033333  0.0500  0.396216  0.946311  0.137907
# 593          mondrian  199   0.418665  0.6075  0.262568  0.819337  0.000522
# 594           datafly  200   0.025017  0.0325  0.382838  0.988104  0.755179
# 595  datafly_shuffled  200   0.033324  0.0825  0.365135  0.949093  0.159284
# 596          mondrian  200   0.397369  0.5700  0.282838  0.834028  0.000900
#
# ...

# %%
birth = pd.read_csv("birth_randoms/metrics.csv")
birth
# Out:
#                  algo   no  precision        dm        cm   entropy   discern  \
# 0             datafly    1   0.472531  0.466667  0.520933  0.723852  0.180107
# 1    datafly_shuffled    1   0.392746  0.333333  0.574457  0.802920  0.326712
# 2            mondrian    1   0.630650  0.866667  0.425543  0.357773  0.011453
# 3             datafly    2   0.401814  0.333333  0.551669  0.767857  0.256308
# 4    datafly_shuffled    2   0.370174  0.333333  0.572867  0.768779  0.248001
# ..                ...  ...        ...       ...       ...       ...       ...
# 595  datafly_shuffled  199   0.333333  0.200000  0.586645  0.837448  0.383618
# 596          mondrian  199   0.590277  0.866667  0.421834  0.387351  0.021104
# 597           datafly  200   0.259259  0.266667  0.567038  0.811682  0.282501
# 598  datafly_shuffled  200   0.388683  0.333333  0.536831  0.755125  0.208323
# 599          mondrian  200   0.567018  0.866667  0.412295  0.355915  0.012748
#
# ...

# %%
adult = pd.read_csv("adult_randoms/metrics.csv")
adult
# Out:
#                  algo   no  precision        dm        cm   entropy   discern  \
# 0             datafly    1   0.184196  0.067073  0.248922  0.882860  0.279394
# 1    datafly_shuffled    1   0.217921  0.085366  0.240634  0.813822  0.127674
# 2            mondrian    1   0.551444  0.817073  0.161296  0.429300  0.000632
# 3             datafly    2   0.167015  0.079268  0.248922  0.925670  0.436592
# 4    datafly_shuffled    2   0.210820  0.067073  0.248922  0.860101  0.231081
# ..                ...  ...        ...       ...       ...       ...       ...
# 595  datafly_shuffled  199   0.240942  0.140244  0.243353  0.777514  0.073246
# 596          mondrian  199   0.553054  0.884146  0.158544  0.493906  0.001710
# 597           datafly  200   0.242756  0.079268  0.206750  0.910911  0.385237
# 598  datafly_shuffled  200   0.168498  0.073171  0.248922  0.897395  0.292923
# 599          mondrian  200   0.558813  0.810976  0.154201  0.442071  0.000677
#
# ...
